# %%
from DashboardView.DV_Code import DashboardView
from HousematesView.HV_Code import HousematesView
from MainWindow.MW_Code import MainWindow
from TasksView.TV_Code import TasksView

if __name__ == "__main__":
    app = MainWindow()
    app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 7
#       4 from TasksView.TV_Code import TasksView
#       6 if __name__ == "__main__":
# ----> 7     app = MainWindow()
#       8     app.mainloop()
#
# File /workspaces/EquiShare/Src/MainWindow/MW_Code.py:4, in MainWindow.__init__(self)
#       3 def __init__(self):
# ----> 4     super().__init__()
#       6     ctk.set_appearance_mode("System")  # "Dark" / "Light"
#       7     ctk.set_default_color_theme("blue")
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/customtkinter/windows/ctk_tk.py:40, in CTk.__init__(self, fg_color, **kwargs)
#      37 self._enable_macos_dark_title_bar()
#      39 # call init methods of super classes
# ---> 40 CTK_PARENT_CLASS.__init__(self, **pop_from_dict_by_set(kwargs, self._valid_tk_constructor_arguments))
#      41 CTkAppearanceModeBaseClass.__init__(self)
# ...
