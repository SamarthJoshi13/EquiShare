# %%
import customtkinter
main_screen=customtkinter.CTk()
main_screen.title("EquiShare")
main_screen.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 import customtkinter
# ----> 2 main_screen=customtkinter.CTk()
#       3 main_screen.title("EquiShare")
#       4 main_screen.mainloop()
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/customtkinter/windows/ctk_tk.py:40, in CTk.__init__(self, fg_color, **kwargs)
#      37 self._enable_macos_dark_title_bar()
#      39 # call init methods of super classes
# ---> 40 CTK_PARENT_CLASS.__init__(self, **pop_from_dict_by_set(kwargs, self._valid_tk_constructor_arguments))
#      41 CTkAppearanceModeBaseClass.__init__(self)
#      42 CTkScalingBaseClass.__init__(self, scaling_type="window")
#
# File /usr/local/python/3.12.1/lib/python3.12/tkinter/__init__.py:2340, in Tk.__init__(self, screenName, baseName, className, useTk, sync, use)
#    2338         baseName = baseName + ext
# ...
